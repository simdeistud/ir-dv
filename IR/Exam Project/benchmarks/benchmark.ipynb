# %% [markdown]
# # Boolean Model implementations benchmarks
# In this notebook we will perform some queries testing all the various features implemented by the IRs.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from src.index import *
from src.IR import *
from src.utils import *

path="C:\\Users\\simone\\source\\repos\\ir-dv\\IR\\Exam Project\\data\\cran.all.1400"
ir1 = BooleanIR()
ir2 = BooleanPermutermIR()
ir3 = BooleanKGRamIR(k=3)
ir1.build(path)
ir2.build(path)
ir3.build(path)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\simone\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Adding document to index [1]
# Adding document to index [2]
# Adding document to index [3]
# Adding document to index [4]
# Adding document to index [5]
# Adding document to index [6]
# Adding document to index [7]
# Adding document to index [8]
# Adding document to index [9]
# Adding document to index [10]
# Adding document to index [11]
# Adding document to index [12]
# Adding document to index [13]
# Adding document to index [14]
# Adding document to index [15]
# Adding document to index [16]
# Adding document to index [17]
# Adding document to index [18]
# Adding document to index [19]
# Adding document to index [20]
# Adding document to index [21]
# Adding document to index [22]
# Adding document to index [23]
# Adding document to index [24]
# Adding document to index [25]
# Adding document to index [26]
# Adding document to index [27]
# Adding document to index [28]
# Adding document to index [29]
# Adding document to index [30]
# Adding document to index [31]
# Adding document to index [32]
# Adding document to index [33]
# Adding document to index [34]
# Adding document to index [35]
# Adding document to index [36]
# Adding document to index [37]
# Adding document to index [38]
# Adding document to index [39]
# Adding document to index [40]
# Adding document to index [41]
# Adding document to index [42]
# Adding document to index [43]
# Adding document to index [44]
# Adding document to index [45]
# Adding document to index [46]
# Adding document to index [47]
# Adding document to index [48]
# Adding document to index [49]
# Adding document to index [50]
# Adding document to index [51]
# Adding document to index [52]
# Adding document to index [53]
# Adding document to index [54]
# Adding document to index [55]
# Adding document to index [56]
# Adding document to index [57]
# Adding document to index [58]
# Adding document to index [59]
# Adding document to index [60]
# Adding document to index [61]
# Adding document to index [62]
# Adding document to index [63]
# Adding document to index [64]
# Adding document to index [65]
# Adding document to index [66]
# Adding document to index [67]
# Adding document to index [68]
# Adding document to index [69]
# Adding document to index [70]
# Adding document to index [71]
# Adding document to index [72]
# Adding document to index [73]
# Adding document to index [74]
# Adding document to index [75]
# Adding document to index [76]
# Adding document to index [77]
# Adding document to index [78]
# Adding document to index [79]
# Adding document to index [80]
# Adding document to index [81]
# Adding document to index [82]
# Adding document to index [83]
# Adding document to index [84]
# Adding document to index [85]
# Adding document to index [86]
# Adding document to index [87]
# Adding document to index [88]
# Adding document to index [89]
# Adding document to index [90]
# Adding document to index [91]
# Adding document to index [92]
# Adding document to index [93]
# Adding document to index [94]
# Adding document to index [95]
# Adding document to index [96]
# Adding document to index [97]
# Adding document to index [98]
# Adding document to index [99]
# Adding document to index [100]
# Adding document to index [101]
# Adding document to index [102]
# Adding document to index [103]
# Adding document to index [104]
# Adding document to index [105]
# Adding document to index [106]
# Adding document to index [107]
# Adding document to index [108]
# Adding document to index [109]
# Adding document to index [110]
# Adding document to index [111]
# Adding document to index [112]
# Adding document to index [113]
# Adding document to index [114]
# Adding document to index [115]
# Adding document to index [116]
# Adding document to index [117]
# Adding document to index [118]
# Adding document to index [119]
# Adding document to index [120]
# Adding document to index [121]
# Adding document to index [122]
# Adding document to index [123]
# Adding document to index [124]
# Adding document to index [125]
# Adding document to index [126]
# Adding document to index [127]
# Adding document to index [128]
# Adding document to index [129]
# Adding document to index [130]
# Adding document to index [131]
# Adding document to index [132]
# Adding document to index [133]
# Adding document to index [134]
# Adding document to index [135]
# Adding document to index [136]
# Adding document to index [137]
# Adding document to index [138]
# Adding document to index [139]
# Adding document to index [140]
# Adding document to index [141]
# Adding document to index [142]
# Adding document to index [143]
# Adding document to index [144]
# Adding document to index [145]
# Adding document to index [146]
# Adding document to index [147]
# Adding document to index [148]
# Adding document to index [149]
# Adding document to index [150]
# Adding document to index [151]
# Adding document to index [152]
# Adding document to index [153]
# Adding document to index [154]
# Adding document to index [155]
# Adding document to index [156]
# Adding document to index [157]
# Adding document to index [158]
# Adding document to index [159]
# Adding document to index [160]
# Adding document to index [161]
# Adding document to index [162]
# Adding document to index [163]
# Adding document to index [164]
# Adding document to index [165]
# Adding document to index [166]
# Adding document to index [167]
# Adding document to index [168]
# Adding document to index [169]
# Adding document to index [170]
# Adding document to index [171]
# Adding document to index [172]
# Adding document to index [173]
# Adding document to index [174]
# Adding document to index [175]
# Adding document to index [176]
# Adding document to index [177]
# Adding document to index [178]
# Adding document to index [179]
# Adding document to index [180]
# Adding document to index [181]
# Adding document to index [182]
# Adding document to index [183]
# Adding document to index [184]
# Adding document to index [185]
# Adding document to index [186]
# Adding document to index [187]
# Adding document to index [188]
# Adding document to index [189]
# Adding document to index [190]
# Adding document to index [191]
# Adding document to index [192]
# Adding document to index [193]
# Adding document to index [194]
# Adding document to index [195]
# Adding document to index [196]
# Adding document to index [197]
# Adding document to index [198]
# Adding document to index [199]
# Adding document to index [200]
# Adding document to index [201]
# Adding document to index [202]
# Adding document to index [203]
# Adding document to index [204]
# Adding document to index [205]
# Adding document to index [206]
# Adding document to index [207]
# Adding document to index [208]
# Adding document to index [209]
# Adding document to index [210]
# Adding document to index [211]
# Adding document to index [212]
# Adding document to index [213]
# Adding document to index [214]
# Adding document to index [215]
# Adding document to index [216]
# Adding document to index [217]
# Adding document to index [218]
# Adding document to index [219]
# Adding document to index [220]
# Adding document to index [221]
# Adding document to index [222]
# Adding document to index [223]
# Adding document to index [224]
# Adding document to index [225]
# Adding document to index [226]
# Adding document to index [227]
# Adding document to index [228]
# Adding document to index [229]
# Adding document to index [230]
# Adding document to index [231]
# Adding document to index [232]
# Adding document to index [233]
# Adding document to index [234]
# Adding document to index [235]
# Adding document to index [236]
# Adding document to index [237]
# Adding document to index [238]
# Adding document to index [239]
# Adding document to index [240]
# Adding document to index [241]
# Adding document to index [242]
# Adding document to index [243]
# Adding document to index [244]
# Adding document to index [245]
# Adding document to index [246]
# Adding document to index [247]
# Adding document to index [248]
# Adding document to index [249]
# Adding document to index [250]
# Adding document to index [251]
# Adding document to index [252]
# Adding document to index [253]
# Adding document to index [254]
# Adding document to index [255]
# Adding document to index [256]
# Adding document to index [257]
# Adding document to index [258]
# Adding document to index [259]
# Adding document to index [260]
# Adding document to index [261]
# Adding document to index [262]
# Adding document to index [263]
# Adding document to index [264]
# Adding document to index [265]
# Adding document to index [266]
# Adding document to index [267]
# Adding document to index [268]
# Adding document to index [269]
# Adding document to index [270]
# Adding document to index [271]
# Adding document to index [272]
# Adding document to index [273]
# Adding document to index [274]
# Adding document to index [275]
# Adding document to index [276]
# Adding document to index [277]
# Adding document to index [278]
# Adding document to index [279]
# Adding document to index [280]
# Adding document to index [281]
# Adding document to index [282]
# Adding document to index [283]
# Adding document to index [284]
# Adding document to index [285]
# Adding document to index [286]
# Adding document to index [287]
# Adding document to index [288]
# Adding document to index [289]
# Adding document to index [290]
# Adding document to index [291]
# Adding document to index [292]
# Adding document to index [293]
# Adding document to index [294]
# Adding document to index [295]
# Adding document to index [296]
# Adding document to index [297]
# Adding document to index [298]
# Adding document to index [299]
# Adding document to index [300]
# Adding document to index [301]
# Adding document to index [302]
# Adding document to index [303]
# Adding document to index [304]
# Adding document to index [305]
# Adding document to index [306]
# Adding document to index [307]
# Adding document to index [308]
# Adding document to index [309]
# Adding document to index [310]
# Adding document to index [311]
# Adding document to index [312]
# Adding document to index [313]
# Adding document to index [314]
# Adding document to index [315]
# Adding document to index [316]
# Adding document to index [317]
# Adding document to index [318]
# Adding document to index [319]
# Adding document to index [320]
# Adding document to index [321]
# Adding document to index [322]
# Adding document to index [323]
# Adding document to index [324]
# Adding document to index [325]
# Adding document to index [326]
# Adding document to index [327]
# Adding document to index [328]
# Adding document to index [329]
# Adding document to index [330]
# Adding document to index [331]
# Adding document to index [332]
# Adding document to index [333]
# Adding document to index [334]
# Adding document to index [335]
# Adding document to index [336]
# Adding document to index [337]
# Adding document to index [338]
# Adding document to index [339]
# Adding document to index [340]
# Adding document to index [341]
# Adding document to index [342]
# Adding document to index [343]
# Adding document to index [344]
# Adding document to index [345]
# Adding document to index [346]
# Adding document to index [347]
# Adding document to index [348]
# Adding document to index [349]
# Adding document to index [350]
# Adding document to index [351]
# Adding document to index [352]
# Adding document to index [353]
# Adding document to index [354]
# Adding document to index [355]
# Adding document to index [356]
# Adding document to index [357]
# Adding document to index [358]
# Adding document to index [359]
# Adding document to index [360]
# Adding document to index [361]
# Adding document to index [362]
# Adding document to index [363]
# Adding document to index [364]
# Adding document to index [365]
# Adding document to index [366]
# Adding document to index [367]
# Adding document to index [368]
# Adding document to index [369]
# Adding document to index [370]
# Adding document to index [371]
# Adding document to index [372]
# Adding document to index [373]
# Adding document to index [374]
# Adding document to index [375]
# Adding document to index [376]
# Adding document to index [377]
# Adding document to index [378]
# Adding document to index [379]
# Adding document to index [380]
# Adding document to index [381]
# Adding document to index [382]
# Adding document to index [383]
# Adding document to index [384]
# Adding document to index [385]
# Adding document to index [386]
# Adding document to index [387]
# Adding document to index [388]
# Adding document to index [389]
# Adding document to index [390]
# Adding document to index [391]
# Adding document to index [392]
# Adding document to index [393]
# Adding document to index [394]
# Adding document to index [395]
# Adding document to index [396]
# Adding document to index [397]
# Adding document to index [398]
# Adding document to index [399]
# Adding document to index [400]
# Adding document to index [401]
# Adding document to index [402]
# Adding document to index [403]
# Adding document to index [404]
# Adding document to index [405]
# Adding document to index [406]
# Adding document to index [407]
# Adding document to index [408]
# Adding document to index [409]
# Adding document to index [410]
# Adding document to index [411]
# Adding document to index [412]
# Adding document to index [413]
# Adding document to index [414]
# Adding document to index [415]
# Adding document to index [416]
# Adding document to index [417]
# Adding document to index [418]
# Adding document to index [419]
# Adding document to index [420]
# Adding document to index [421]
# Adding document to index [422]
# Adding document to index [423]
# Adding document to index [424]
# Adding document to index [425]
# Adding document to index [426]
# Adding document to index [427]
# Adding document to index [428]
# Adding document to index [429]
# Adding document to index [430]
# Adding document to index [431]
# Adding document to index [432]
# Adding document to index [433]
# Adding document to index [434]
# Adding document to index [435]
# Adding document to index [436]
# Adding document to index [437]
# Adding document to index [438]
# Adding document to index [439]
# Adding document to index [440]
# Adding document to index [441]
# Adding document to index [442]
# Adding document to index [443]
# Adding document to index [444]
# Adding document to index [445]
# Adding document to index [446]
# Adding document to index [447]
# Adding document to index [448]
# Adding document to index [449]
# Adding document to index [450]
# Adding document to index [451]
# Adding document to index [452]
# Adding document to index [453]
# Adding document to index [454]
# Adding document to index [455]
# Adding document to index [456]
# Adding document to index [457]
# Adding document to index [458]
# Adding document to index [459]
# Adding document to index [460]
# Adding document to index [461]
# Adding document to index [462]
# Adding document to index [463]
# Adding document to index [464]
# Adding document to index [465]
# Adding document to index [466]
# Adding document to index [467]
# Adding document to index [468]
# Adding document to index [469]
# Adding document to index [470]
# Adding document to index [471]
# Adding document to index [472]
# Adding document to index [473]
# Adding document to index [474]
# Adding document to index [475]
# Adding document to index [476]
# Adding document to index [477]
# Adding document to index [478]
# Adding document to index [479]
# Adding document to index [480]
# Adding document to index [481]
# Adding document to index [482]
# Adding document to index [483]
# Adding document to index [484]
# Adding document to index [485]
# Adding document to index [486]
# Adding document to index [487]
# Adding document to index [488]
# Adding document to index [489]
# Adding document to index [490]
# Adding document to index [491]
# Adding document to index [492]
# Adding document to index [493]
# Adding document to index [494]
# Adding document to index [495]
# Adding document to index [496]
# Adding document to index [497]
# Adding document to index [498]
# Adding document to index [499]
# Adding document to index [500]
# Adding document to index [501]
# Adding document to index [502]
# Adding document to index [503]
# Adding document to index [504]
# Adding document to index [505]
# Adding document to index [506]
# Adding document to index [507]
# Adding document to index [508]
# Adding document to index [509]
# Adding document to index [510]
# Adding document to index [511]
# Adding document to index [512]
# Adding document to index [513]
# Adding document to index [514]
# Adding document to index [515]
# Adding document to index [516]
# Adding document to index [517]
# Adding document to index [518]
# Adding document to index [519]
# Adding document to index [520]
# Adding document to index [521]
# Adding document to index [522]
# Adding document to index [523]
# Adding document to index [524]
# Adding document to index [525]
# Adding document to index [526]
# Adding document to index [527]
# Adding document to index [528]
# Adding document to index [529]
# Adding document to index [530]
# Adding document to index [531]
# Adding document to index [532]
# Adding document to index [533]
# Adding document to index [534]
# Adding document to index [535]
# Adding document to index [536]
# Adding document to index [537]
# Adding document to index [538]
# Adding document to index [539]
# Adding document to index [540]
# Adding document to index [541]
# Adding document to index [542]
# Adding document to index [543]
# Adding document to index [544]
# Adding document to index [545]
# Adding document to index [546]
# Adding document to index [547]
# Adding document to index [548]
# Adding document to index [549]
# Adding document to index [550]
# Adding document to index [551]
# Adding document to index [552]
# Adding document to index [553]
# Adding document to index [554]
# Adding document to index [555]
# Adding document to index [556]
# Adding document to index [557]
# Adding document to index [558]
# Adding document to index [559]
# Adding document to index [560]
# Adding document to index [561]
# Adding document to index [562]
# Adding document to index [563]
# Adding document to index [564]
# Adding document to index [565]
# Adding document to index [566]
# Adding document to index [567]
# Adding document to index [568]
# Adding document to index [569]
# Adding document to index [570]
# Adding document to index [571]
# Adding document to index [572]
# Adding document to index [573]
# Adding document to index [574]
# Adding document to index [575]
# Adding document to index [576]
# Adding document to index [577]
# Adding document to index [578]
# Adding document to index [579]
# Adding document to index [580]
# Adding document to index [581]
# Adding document to index [582]
# Adding document to index [583]
# Adding document to index [584]
# Adding document to index [585]
# Adding document to index [586]
# Adding document to index [587]
# Adding document to index [588]
# Adding document to index [589]
# Adding document to index [590]
# Adding document to index [591]
# Adding document to index [592]
# Adding document to index [593]
# Adding document to index [594]
# Adding document to index [595]
# Adding document to index [596]
# Adding document to index [597]
# Adding document to index [598]
# Adding document to index [599]
# Adding document to index [600]
# Adding document to index [601]
# Adding document to index [602]
# Adding document to index [603]
# Adding document to index [604]
# Adding document to index [605]
# Adding document to index [606]
# Adding document to index [607]
# Adding document to index [608]
# Adding document to index [609]
# Adding document to index [610]
# Adding document to index [611]
# Adding document to index [612]
# Adding document to index [613]
# Adding document to index [614]
# Adding document to index [615]
# Adding document to index [616]
# Adding document to index [617]
# Adding document to index [618]
# Adding document to index [619]
# Adding document to index [620]
# Adding document to index [621]
# Adding document to index [622]
# Adding document to index [623]
# Adding document to index [624]
# Adding document to index [625]
# Adding document to index [626]
# Adding document to index [627]
# Adding document to index [628]
# Adding document to index [629]
# Adding document to index [630]
# Adding document to index [631]
# Adding document to index [632]
# Adding document to index [633]
# Adding document to index [634]
# Adding document to index [635]
# Adding document to index [636]
# Adding document to index [637]
# Adding document to index [638]
# Adding document to index [639]
# Adding document to index [640]
# Adding document to index [641]
# Adding document to index [642]
# Adding document to index [643]
# Adding document to index [644]
# Adding document to index [645]
# Adding document to index [646]
# Adding document to index [647]
# Adding document to index [648]
# Adding document to index [649]
# Adding document to index [650]
# Adding document to index [651]
# Adding document to index [652]
# Adding document to index [653]
# Adding document to index [654]
# Adding document to index [655]
# Adding document to index [656]
# Adding document to index [657]
# Adding document to index [658]
# Adding document to index [659]
# Adding document to index [660]
# Adding document to index [661]
# Adding document to index [662]
# Adding document to index [663]
# Adding document to index [664]
# Adding document to index [665]
# Adding document to index [666]
# Adding document to index [667]
# Adding document to index [668]
# Adding document to index [669]
# Adding document to index [670]
# Adding document to index [671]
# Adding document to index [672]
# Adding document to index [673]
# Adding document to index [674]
# Adding document to index [675]
# Adding document to index [676]
# Adding document to index [677]
# Adding document to index [678]
# Adding document to index [679]
# Adding document to index [680]
# Adding document to index [681]
# Adding document to index [682]
# Adding document to index [683]
# Adding document to index [684]
# Adding document to index [685]
# Adding document to index [686]
# Adding document to index [687]
# Adding document to index [688]
# Adding document to index [689]
# Adding document to index [690]
# Adding document to index [691]
# Adding document to index [692]
# Adding document to index [693]
# Adding document to index [694]
# Adding document to index [695]
# Adding document to index [696]
# Adding document to index [697]
# Adding document to index [698]
# Adding document to index [699]
# Adding document to index [700]
# Adding document to index [701]
# Adding document to index [702]
# Adding document to index [703]
# Adding document to index [704]
# Adding document to index [705]
# Adding document to index [706]
# Adding document to index [707]
# Adding document to index [708]
# Adding document to index [709]
# Adding document to index [710]
# Adding document to index [711]
# Adding document to index [712]
# Adding document to index [713]
# Adding document to index [714]
# Adding document to index [715]
# Adding document to index [716]
# Adding document to index [717]
# Adding document to index [718]
# Adding document to index [719]
# Adding document to index [720]
# Adding document to index [721]
# Adding document to index [722]
# Adding document to index [723]
# Adding document to index [724]
# Adding document to index [725]
# Adding document to index [726]
# Adding document to index [727]
# Adding document to index [728]
# Adding document to index [729]
# Adding document to index [730]
# Adding document to index [731]
# Adding document to index [732]
# Adding document to index [733]
# Adding document to index [734]
# Adding document to index [735]
# Adding document to index [736]
# Adding document to index [737]
# Adding document to index [738]
# Adding document to index [739]
# Adding document to index [740]
# Adding document to index [741]
# Adding document to index [742]
# Adding document to index [743]
# Adding document to index [744]
# Adding document to index [745]
# Adding document to index [746]
# Adding document to index [747]
# Adding document to index [748]
# Adding document to index [749]
# Adding document to index [750]
# Adding document to index [751]
# Adding document to index [752]
# Adding document to index [753]
# Adding document to index [754]
# Adding document to index [755]
# Adding document to index [756]
# Adding document to index [757]
# Adding document to index [758]
# Adding document to index [759]
# Adding document to index [760]
# Adding document to index [761]
# Adding document to index [762]
# Adding document to index [763]
# Adding document to index [764]
# Adding document to index [765]
# Adding document to index [766]
# Adding document to index [767]
# Adding document to index [768]
# Adding document to index [769]
# Adding document to index [770]
# Adding document to index [771]
# Adding document to index [772]
# Adding document to index [773]
# Adding document to index [774]
# Adding document to index [775]
# Adding document to index [776]
# Adding document to index [777]
# Adding document to index [778]
# Adding document to index [779]
# Adding document to index [780]
# Adding document to index [781]
# Adding document to index [782]
# Adding document to index [783]
# Adding document to index [784]
# Adding document to index [785]
# Adding document to index [786]
# Adding document to index [787]
# Adding document to index [788]
# Adding document to index [789]
# Adding document to index [790]
# Adding document to index [791]
# Adding document to index [792]
# Adding document to index [793]
# Adding document to index [794]
# Adding document to index [795]
# Adding document to index [796]
# Adding document to index [797]
# Adding document to index [798]
# Adding document to index [799]
# Adding document to index [800]
# Adding document to index [801]
# Adding document to index [802]
# Adding document to index [803]
# Adding document to index [804]
# Adding document to index [805]
# Adding document to index [806]
# Adding document to index [807]
# Adding document to index [808]
# Adding document to index [809]
# Adding document to index [810]
# Adding document to index [811]
# Adding document to index [812]
# Adding document to index [813]
# Adding document to index [814]
# Adding document to index [815]
# Adding document to index [816]
# Adding document to index [817]
# Adding document to index [818]
# Adding document to index [819]
# Adding document to index [820]
# Adding document to index [821]
# Adding document to index [822]
# Adding document to index [823]
# Adding document to index [824]
# Adding document to index [825]
# Adding document to index [826]
# Adding document to index [827]
# Adding document to index [828]
# Adding document to index [829]
# Adding document to index [830]
# Adding document to index [831]
# Adding document to index [832]
# Adding document to index [833]
# Adding document to index [834]
# Adding document to index [835]
# Adding document to index [836]
# Adding document to index [837]
# Adding document to index [838]
# Adding document to index [839]
# Adding document to index [840]
# Adding document to index [841]
# Adding document to index [842]
# Adding document to index [843]
# Adding document to index [844]
# Adding document to index [845]
# Adding document to index [846]
# Adding document to index [847]
# Adding document to index [848]
# Adding document to index [849]
# Adding document to index [850]
# Adding document to index [851]
# Adding document to index [852]
# Adding document to index [853]
# Adding document to index [854]
# Adding document to index [855]
# Adding document to index [856]
# Adding document to index [857]
# Adding document to index [858]
# Adding document to index [859]
# Adding document to index [860]
# Adding document to index [861]
# Adding document to index [862]
# Adding document to index [863]
# Adding document to index [864]
# Adding document to index [865]
# Adding document to index [866]
# Adding document to index [867]
# Adding document to index [868]
# Adding document to index [869]
# Adding document to index [870]
# Adding document to index [871]
# Adding document to index [872]
# Adding document to index [873]
# Adding document to index [874]
# Adding document to index [875]
# Adding document to index [876]
# Adding document to index [877]
# Adding document to index [878]
# Adding document to index [879]
# Adding document to index [880]
# Adding document to index [881]
# Adding document to index [882]
# Adding document to index [883]
# Adding document to index [884]
# Adding document to index [885]
# Adding document to index [886]
# Adding document to index [887]
# Adding document to index [888]
# Adding document to index [889]
# Adding document to index [890]
# Adding document to index [891]
# Adding document to index [892]
# Adding document to index [893]
# Adding document to index [894]
# Adding document to index [895]
# Adding document to index [896]
# Adding document to index [897]
# Adding document to index [898]
# Adding document to index [899]
# Adding document to index [900]
# Adding document to index [901]
# Adding document to index [902]
# Adding document to index [903]
# Adding document to index [904]
# Adding document to index [905]
# Adding document to index [906]
# Adding document to index [907]
# Adding document to index [908]
# Adding document to index [909]
# Adding document to index [910]
# Adding document to index [911]
# Adding document to index [912]
# Adding document to index [913]
# Adding document to index [914]
# Adding document to index [915]
# Adding document to index [916]
# Adding document to index [917]
# Adding document to index [918]
# Adding document to index [919]
# Adding document to index [920]
# Adding document to index [921]
# Adding document to index [922]
# Adding document to index [923]
# Adding document to index [924]
# Adding document to index [925]
# Adding document to index [926]
# Adding document to index [927]
# Adding document to index [928]
# Adding document to index [929]
# Adding document to index [930]
# Adding document to index [931]
# Adding document to index [932]
# Adding document to index [933]
# Adding document to index [934]
# Adding document to index [935]
# Adding document to index [936]
# Adding document to index [937]
# Adding document to index [938]
# Adding document to index [939]
# Adding document to index [940]
# Adding document to index [941]
# Adding document to index [942]
# Adding document to index [943]
# Adding document to index [944]
# Adding document to index [945]
# Adding document to index [946]
# Adding document to index [947]
# Adding document to index [948]
# Adding document to index [949]
# Adding document to index [950]
# Adding document to index [951]
# Adding document to index [952]
# Adding document to index [953]
# Adding document to index [954]
# Adding document to index [955]
# Adding document to index [956]
# Adding document to index [957]
# Adding document to index [958]
# Adding document to index [959]
# Adding document to index [960]
# Adding document to index [961]
# Adding document to index [962]
# Adding document to index [963]
# Adding document to index [964]
# Adding document to index [965]
# Adding document to index [966]
# Adding document to index [967]
# Adding document to index [968]
# Adding document to index [969]
# Adding document to index [970]
# Adding document to index [971]
# Adding document to index [972]
# Adding document to index [973]
# Adding document to index [974]
# Adding document to index [975]
# Adding document to index [976]
# Adding document to index [977]
# Adding document to index [978]
# Adding document to index [979]
# Adding document to index [980]
# Adding document to index [981]
# Adding document to index [982]
# Adding document to index [983]
# Adding document to index [984]
# Adding document to index [985]
# Adding document to index [986]
# Adding document to index [987]
# Adding document to index [988]
# Adding document to index [989]
# Adding document to index [990]
# Adding document to index [991]
# Adding document to index [992]
# Adding document to index [993]
# Adding document to index [994]
# Adding document to index [995]
# Adding document to index [996]
# Adding document to index [997]
# Adding document to index [998]
# Adding document to index [999]
# Adding document to index [1000]
# Adding document to index [1001]
# Adding document to index [1002]
# Adding document to index [1003]
# Adding document to index [1004]
# Adding document to index [1005]
# Adding document to index [1006]
# Adding document to index [1007]
# Adding document to index [1008]
# Adding document to index [1009]
# Adding document to index [1010]
# Adding document to index [1011]
# Adding document to index [1012]
# Adding document to index [1013]
# Adding document to index [1014]
# Adding document to index [1015]
# Adding document to index [1016]
# Adding document to index [1017]
# Adding document to index [1018]
# Adding document to index [1019]
# Adding document to index [1020]
# Adding document to index [1021]
# Adding document to index [1022]
# Adding document to index [1023]
# Adding document to index [1024]
# Adding document to index [1025]
# Adding document to index [1026]
# Adding document to index [1027]
# Adding document to index [1028]
# Adding document to index [1029]
# Adding document to index [1030]
# Adding document to index [1031]
# Adding document to index [1032]
# Adding document to index [1033]
# Adding document to index [1034]
# Adding document to index [1035]
# Adding document to index [1036]
# Adding document to index [1037]
# Adding document to index [1038]
# Adding document to index [1039]
# Adding document to index [1040]
# Adding document to index [1041]
# Adding document to index [1042]
# Adding document to index [1043]
# Adding document to index [1044]
# Adding document to index [1045]
# Adding document to index [1046]
# Adding document to index [1047]
# Adding document to index [1048]
# Adding document to index [1049]
# Adding document to index [1050]
# Adding document to index [1051]
# Adding document to index [1052]
# Adding document to index [1053]
# Adding document to index [1054]
# Adding document to index [1055]
# Adding document to index [1056]
# Adding document to index [1057]
# Adding document to index [1058]
# Adding document to index [1059]
# Adding document to index [1060]
# Adding document to index [1061]
# Adding document to index [1062]
# Adding document to index [1063]
# Adding document to index [1064]
# Adding document to index [1065]
# Adding document to index [1066]
# Adding document to index [1067]
# Adding document to index [1068]
# Adding document to index [1069]
# Adding document to index [1070]
# Adding document to index [1071]
# Adding document to index [1072]
# Adding document to index [1073]
# Adding document to index [1074]
# Adding document to index [1075]
# Adding document to index [1076]
# Adding document to index [1077]
# Adding document to index [1078]
# Adding document to index [1079]
# Adding document to index [1080]
# Adding document to index [1081]
# Adding document to index [1082]
# Adding document to index [1083]
# Adding document to index [1084]
# Adding document to index [1085]
# Adding document to index [1086]
# Adding document to index [1087]
# Adding document to index [1088]
# Adding document to index [1089]
# Adding document to index [1090]
# Adding document to index [1091]
# Adding document to index [1092]
# Adding document to index [1093]
# Adding document to index [1094]
# Adding document to index [1095]
# Adding document to index [1096]
# Adding document to index [1097]
# Adding document to index [1098]
# Adding document to index [1099]
# Adding document to index [1100]
# Adding document to index [1101]
# Adding document to index [1102]
# Adding document to index [1103]
# Adding document to index [1104]
# Adding document to index [1105]
# Adding document to index [1106]
# Adding document to index [1107]
# Adding document to index [1108]
# Adding document to index [1109]
# Adding document to index [1110]
# Adding document to index [1111]
# Adding document to index [1112]
# Adding document to index [1113]
# Adding document to index [1114]
# Adding document to index [1115]
# Adding document to index [1116]
# Adding document to index [1117]
# Adding document to index [1118]
# Adding document to index [1119]
# Adding document to index [1120]
# Adding document to index [1121]
# Adding document to index [1122]
# Adding document to index [1123]
# Adding document to index [1124]
# Adding document to index [1125]
# Adding document to index [1126]
# Adding document to index [1127]
# Adding document to index [1128]
# Adding document to index [1129]
# Adding document to index [1130]
# Adding document to index [1131]
# Adding document to index [1132]
# Adding document to index [1133]
# Adding document to index [1134]
# Adding document to index [1135]
# Adding document to index [1136]
# Adding document to index [1137]
# Adding document to index [1138]
# Adding document to index [1139]
# Adding document to index [1140]
# Adding document to index [1141]
# Adding document to index [1142]
# Adding document to index [1143]
# Adding document to index [1144]
# Adding document to index [1145]
# Adding document to index [1146]
# Adding document to index [1147]
# Adding document to index [1148]
# Adding document to index [1149]
# Adding document to index [1150]
# Adding document to index [1151]
# Adding document to index [1152]
# Adding document to index [1153]
# Adding document to index [1154]
# Adding document to index [1155]
# Adding document to index [1156]
# Adding document to index [1157]
# Adding document to index [1158]
# Adding document to index [1159]
# Adding document to index [1160]
# Adding document to index [1161]
# Adding document to index [1162]
# Adding document to index [1163]
# Adding document to index [1164]
# Adding document to index [1165]
# Adding document to index [1166]
# Adding document to index [1167]
# Adding document to index [1168]
# Adding document to index [1169]
# Adding document to index [1170]
# Adding document to index [1171]
# Adding document to index [1172]
# Adding document to index [1173]
# Adding document to index [1174]
# Adding document to index [1175]
# Adding document to index [1176]
# Adding document to index [1177]
# Adding document to index [1178]
# Adding document to index [1179]
# Adding document to index [1180]
# Adding document to index [1181]
# Adding document to index [1182]
# Adding document to index [1183]
# Adding document to index [1184]
# Adding document to index [1185]
# Adding document to index [1186]
# Adding document to index [1187]
# Adding document to index [1188]
# Adding document to index [1189]
# Adding document to index [1190]
# Adding document to index [1191]
# Adding document to index [1192]
# Adding document to index [1193]
# Adding document to index [1194]
# Adding document to index [1195]
# Adding document to index [1196]
# Adding document to index [1197]
# Adding document to index [1198]
# Adding document to index [1199]
# Adding document to index [1200]
# Adding document to index [1201]
# Adding document to index [1202]
# Adding document to index [1203]
# Adding document to index [1204]
# Adding document to index [1205]
# Adding document to index [1206]
# Adding document to index [1207]
# Adding document to index [1208]
# Adding document to index [1209]
# Adding document to index [1210]
# Adding document to index [1211]
# Adding document to index [1212]
# Adding document to index [1213]
# Adding document to index [1214]
# Adding document to index [1215]
# Adding document to index [1216]
# Adding document to index [1217]
# Adding document to index [1218]
# Adding document to index [1219]
# Adding document to index [1220]
# Adding document to index [1221]
# Adding document to index [1222]
# Adding document to index [1223]
# Adding document to index [1224]
# Adding document to index [1225]
# Adding document to index [1226]
# Adding document to index [1227]
# Adding document to index [1228]
# Adding document to index [1229]
# Adding document to index [1230]
# Adding document to index [1231]
# Adding document to index [1232]
# Adding document to index [1233]
# Adding document to index [1234]
# Adding document to index [1235]
# Adding document to index [1236]
# Adding document to index [1237]
# Adding document to index [1238]
# Adding document to index [1239]
# Adding document to index [1240]
# Adding document to index [1241]
# Adding document to index [1242]
# Adding document to index [1243]
# Adding document to index [1244]
# Adding document to index [1245]
# Adding document to index [1246]
# Adding document to index [1247]
# Adding document to index [1248]
# Adding document to index [1249]
# Adding document to index [1250]
# Adding document to index [1251]
# Adding document to index [1252]
# Adding document to index [1253]
# Adding document to index [1254]
# Adding document to index [1255]
# Adding document to index [1256]
# Adding document to index [1257]
# Adding document to index [1258]
# Adding document to index [1259]
# Adding document to index [1260]
# Adding document to index [1261]
# Adding document to index [1262]
# Adding document to index [1263]
# Adding document to index [1264]
# Adding document to index [1265]
# Adding document to index [1266]
# Adding document to index [1267]
# Adding document to index [1268]
# Adding document to index [1269]
# Adding document to index [1270]
# Adding document to index [1271]
# Adding document to index [1272]
# Adding document to index [1273]
# Adding document to index [1274]
# Adding document to index [1275]
# Adding document to index [1276]
# Adding document to index [1277]
# Adding document to index [1278]
# Adding document to index [1279]
# Adding document to index [1280]
# Adding document to index [1281]
# Adding document to index [1282]
# Adding document to index [1283]
# Adding document to index [1284]
# Adding document to index [1285]
# Adding document to index [1286]
# Adding document to index [1287]
# Adding document to index [1288]
# Adding document to index [1289]
# Adding document to index [1290]
# Adding document to index [1291]
# Adding document to index [1292]
# Adding document to index [1293]
# Adding document to index [1294]
# Adding document to index [1295]
# Adding document to index [1296]
# Adding document to index [1297]
# Adding document to index [1298]
# Adding document to index [1299]
# Adding document to index [1300]
# Adding document to index [1301]
# Adding document to index [1302]
# Adding document to index [1303]
# Adding document to index [1304]
# Adding document to index [1305]
# Adding document to index [1306]
# Adding document to index [1307]
# Adding document to index [1308]
# Adding document to index [1309]
# Adding document to index [1310]
# Adding document to index [1311]
# Adding document to index [1312]
# Adding document to index [1313]
# Adding document to index [1314]
# Adding document to index [1315]
# Adding document to index [1316]
# Adding document to index [1317]
# Adding document to index [1318]
# Adding document to index [1319]
# Adding document to index [1320]
# Adding document to index [1321]
# Adding document to index [1322]
# Adding document to index [1323]
# Adding document to index [1324]
# Adding document to index [1325]
# Adding document to index [1326]
# Adding document to index [1327]
# Adding document to index [1328]
# Adding document to index [1329]
# Adding document to index [1330]
# Adding document to index [1331]
# Adding document to index [1332]
# Adding document to index [1333]
# Adding document to index [1334]
# Adding document to index [1335]
# Adding document to index [1336]
# Adding document to index [1337]
# Adding document to index [1338]
# Adding document to index [1339]
# Adding document to index [1340]
# Adding document to index [1341]
# Adding document to index [1342]
# Adding document to index [1343]
# Adding document to index [1344]
# Adding document to index [1345]
# Adding document to index [1346]
# Adding document to index [1347]
# Adding document to index [1348]
# Adding document to index [1349]
# Adding document to index [1350]
# Adding document to index [1351]
# Adding document to index [1352]
# Adding document to index [1353]
# Adding document to index [1354]
# Adding document to index [1355]
# Adding document to index [1356]
# Adding document to index [1357]
# Adding document to index [1358]
# Adding document to index [1359]
# Adding document to index [1360]
# Adding document to index [1361]
# Adding document to index [1362]
# Adding document to index [1363]
# Adding document to index [1364]
# Adding document to index [1365]
# Adding document to index [1366]
# Adding document to index [1367]
# Adding document to index [1368]
# Adding document to index [1369]
# Adding document to index [1370]
# Adding document to index [1371]
# Adding document to index [1372]
# Adding document to index [1373]
# Adding document to index [1374]
# Adding document to index [1375]
# Adding document to index [1376]
# Adding document to index [1377]
# Adding document to index [1378]
# Adding document to index [1379]
# Adding document to index [1380]
# Adding document to index [1381]
# Adding document to index [1382]
# Adding document to index [1383]
# Adding document to index [1384]
# Adding document to index [1385]
# Adding document to index [1386]
# Adding document to index [1387]
# Adding document to index [1388]
# Adding document to index [1389]
# Adding document to index [1390]
# Adding document to index [1391]
# Adding document to index [1392]
# Adding document to index [1393]
# Adding document to index [1394]
# Adding document to index [1395]
# Adding document to index [1396]
# Adding document to index [1397]
# Adding document to index [1398]
# Adding document to index [1399]
# Adding document to index [1400]
# Adding document to index [1]
# Adding document to index [2]
# Adding document to index [3]
# Adding document to index [4]
# Adding document to index [5]
# Adding document to index [6]
# Adding document to index [7]
# Adding document to index [8]
# Adding document to index [9]
# Adding document to index [10]
# Adding document to index [11]
# Adding document to index [12]
# Adding document to index [13]
# Adding document to index [14]
# Adding document to index [15]
# Adding document to index [16]
# Adding document to index [17]
# Adding document to index [18]
# Adding document to index [19]
# Adding document to index [20]
# Adding document to index [21]
# Adding document to index [22]
# Adding document to index [23]
# Adding document to index [24]
# Adding document to index [25]
# Adding document to index [26]
# Adding document to index [27]
# Adding document to index [28]
# Adding document to index [29]
# Adding document to index [30]
# Adding document to index [31]
# Adding document to index [32]
# Adding document to index [33]
# Adding document to index [34]
# Adding document to index [35]
# Adding document to index [36]
# Adding document to index [37]
# Adding document to index [38]
# Adding document to index [39]
# Adding document to index [40]
# Adding document to index [41]
# Adding document to index [42]
# Adding document to index [43]
# Adding document to index [44]
# Adding document to index [45]
# Adding document to index [46]
# Adding document to index [47]
# Adding document to index [48]
# Adding document to index [49]
# Adding document to index [50]
# Adding document to index [51]
# Adding document to index [52]
# Adding document to index [53]
# Adding document to index [54]
# Adding document to index [55]
# Adding document to index [56]
# Adding document to index [57]
# Adding document to index [58]
# Adding document to index [59]
# Adding document to index [60]
# Adding document to index [61]
# Adding document to index [62]
# Adding document to index [63]
# Adding document to index [64]
# Adding document to index [65]
# Adding document to index [66]
# Adding document to index [67]
# Adding document to index [68]
# Adding document to index [69]
# Adding document to index [70]
# Adding document to index [71]
# Adding document to index [72]
# Adding document to index [73]
# Adding document to index [74]
# Adding document to index [75]
# Adding document to index [76]
# Adding document to index [77]
# Adding document to index [78]
# Adding document to index [79]
# Adding document to index [80]
# Adding document to index [81]
# Adding document to index [82]
# Adding document to index [83]
# Adding document to index [84]
# Adding document to index [85]
# Adding document to index [86]
# Adding document to index [87]
# Adding document to index [88]
# Adding document to index [89]
# Adding document to index [90]
# Adding document to index [91]
# Adding document to index [92]
# Adding document to index [93]
# Adding document to index [94]
# Adding document to index [95]
# Adding document to index [96]
# Adding document to index [97]
# Adding document to index [98]
# Adding document to index [99]
# Adding document to index [100]
# Adding document to index [101]
# Adding document to index [102]
# Adding document to index [103]
# Adding document to index [104]
# Adding document to index [105]
# Adding document to index [106]
# Adding document to index [107]
# Adding document to index [108]
# Adding document to index [109]
# Adding document to index [110]
# Adding document to index [111]
# Adding document to index [112]
# Adding document to index [113]
# Adding document to index [114]
# Adding document to index [115]
# Adding document to index [116]
# Adding document to index [117]
# Adding document to index [118]
# Adding document to index [119]
# Adding document to index [120]
# Adding document to index [121]
# Adding document to index [122]
# Adding document to index [123]
# Adding document to index [124]
# Adding document to index [125]
# Adding document to index [126]
# Adding document to index [127]
# Adding document to index [128]
# Adding document to index [129]
# Adding document to index [130]
# Adding document to index [131]
# Adding document to index [132]
# Adding document to index [133]
# Adding document to index [134]
# Adding document to index [135]
# Adding document to index [136]
# Adding document to index [137]
# ...
# Adding document to index [898]
# Adding document to index [899]
# Adding document to index [900]
# Adding document to index [901]
# Adding document to index [902]
# Adding document to index [903]
# Adding document to index [904]
# Adding document to index [905]
# Adding document to index [906]
# Adding document to index [907]
# Adding document to index [908]
# Adding document to index [909]
# Adding document to index [910]
# Adding document to index [911]
# Adding document to index [912]
# Adding document to index [913]
# Adding document to index [914]
# Adding document to index [915]
# Adding document to index [916]
# Adding document to index [917]
# Adding document to index [918]
# Adding document to index [919]
# Adding document to index [920]
# Adding document to index [921]
# Adding document to index [922]
# Adding document to index [923]
# Adding document to index [924]
# Adding document to index [925]
# Adding document to index [926]
# Adding document to index [927]
# Adding document to index [928]
# Adding document to index [929]
# Adding document to index [930]
# Adding document to index [931]
# Adding document to index [932]
# Adding document to index [933]
# Adding document to index [934]
# Adding document to index [935]
# Adding document to index [936]
# Adding document to index [937]
# Adding document to index [938]
# Adding document to index [939]
# Adding document to index [940]
# Adding document to index [941]
# Adding document to index [942]
# Adding document to index [943]
# Adding document to index [944]
# Adding document to index [945]
# Adding document to index [946]
# Adding document to index [947]
# Adding document to index [948]
# Adding document to index [949]
# Adding document to index [950]
# Adding document to index [951]
# Adding document to index [952]
# Adding document to index [953]
# Adding document to index [954]
# Adding document to index [955]
# Adding document to index [956]
# Adding document to index [957]
# Adding document to index [958]
# Adding document to index [959]
# Adding document to index [960]
# Adding document to index [961]
# Adding document to index [962]
# Adding document to index [963]
# Adding document to index [964]
# Adding document to index [965]
# Adding document to index [966]
# Adding document to index [967]
# Adding document to index [968]
# Adding document to index [969]
# Adding document to index [970]
# Adding document to index [971]
# Adding document to index [972]
# Adding document to index [973]
# Adding document to index [974]
# Adding document to index [975]
# Adding document to index [976]
# Adding document to index [977]
# Adding document to index [978]
# Adding document to index [979]
# Adding document to index [980]
# Adding document to index [981]
# Adding document to index [982]
# Adding document to index [983]
# Adding document to index [984]
# Adding document to index [985]
# Adding document to index [986]
# Adding document to index [987]
# Adding document to index [988]
# Adding document to index [989]
# Adding document to index [990]
# Adding document to index [991]
# Adding document to index [992]
# Adding document to index [993]
# Adding document to index [994]
# Adding document to index [995]
# Adding document to index [996]
# Adding document to index [997]
# Adding document to index [998]
# Adding document to index [999]
# Adding document to index [1000]
# Adding document to index [1001]
# Adding document to index [1002]
# Adding document to index [1003]
# Adding document to index [1004]
# Adding document to index [1005]
# Adding document to index [1006]
# Adding document to index [1007]
# Adding document to index [1008]
# Adding document to index [1009]
# Adding document to index [1010]
# Adding document to index [1011]
# Adding document to index [1012]
# Adding document to index [1013]
# Adding document to index [1014]
# Adding document to index [1015]
# Adding document to index [1016]
# Adding document to index [1017]
# Adding document to index [1018]
# Adding document to index [1019]
# Adding document to index [1020]
# Adding document to index [1021]
# Adding document to index [1022]
# Adding document to index [1023]
# Adding document to index [1024]
# Adding document to index [1025]
# Adding document to index [1026]
# Adding document to index [1027]
# Adding document to index [1028]
# Adding document to index [1029]
# Adding document to index [1030]
# Adding document to index [1031]
# Adding document to index [1032]
# Adding document to index [1033]
# Adding document to index [1034]
# Adding document to index [1035]
# Adding document to index [1036]
# Adding document to index [1037]
# Adding document to index [1038]
# Adding document to index [1039]
# Adding document to index [1040]
# Adding document to index [1041]
# Adding document to index [1042]
# Adding document to index [1043]
# Adding document to index [1044]
# Adding document to index [1045]
# Adding document to index [1046]
# Adding document to index [1047]
# Adding document to index [1048]
# Adding document to index [1049]
# Adding document to index [1050]
# Adding document to index [1051]
# Adding document to index [1052]
# Adding document to index [1053]
# Adding document to index [1054]
# Adding document to index [1055]
# Adding document to index [1056]
# Adding document to index [1057]
# Adding document to index [1058]
# Adding document to index [1059]
# Adding document to index [1060]
# Adding document to index [1061]
# Adding document to index [1062]
# Adding document to index [1063]
# Adding document to index [1064]
# Adding document to index [1065]
# Adding document to index [1066]
# Adding document to index [1067]
# Adding document to index [1068]
# Adding document to index [1069]
# Adding document to index [1070]
# Adding document to index [1071]
# Adding document to index [1072]
# Adding document to index [1073]
# Adding document to index [1074]
# Adding document to index [1075]
# Adding document to index [1076]
# Adding document to index [1077]
# Adding document to index [1078]
# Adding document to index [1079]
# Adding document to index [1080]
# Adding document to index [1081]
# Adding document to index [1082]
# Adding document to index [1083]
# Adding document to index [1084]
# Adding document to index [1085]
# Adding document to index [1086]
# Adding document to index [1087]
# Adding document to index [1088]
# Adding document to index [1089]
# Adding document to index [1090]
# Adding document to index [1091]
# Adding document to index [1092]
# Adding document to index [1093]
# Adding document to index [1094]
# Adding document to index [1095]
# Adding document to index [1096]
# Adding document to index [1097]
# Adding document to index [1098]
# Adding document to index [1099]
# Adding document to index [1100]
# Adding document to index [1101]
# Adding document to index [1102]
# Adding document to index [1103]
# Adding document to index [1104]
# Adding document to index [1105]
# Adding document to index [1106]
# Adding document to index [1107]
# Adding document to index [1108]
# Adding document to index [1109]
# Adding document to index [1110]
# Adding document to index [1111]
# Adding document to index [1112]
# Adding document to index [1113]
# Adding document to index [1114]
# Adding document to index [1115]
# Adding document to index [1116]
# Adding document to index [1117]
# Adding document to index [1118]
# Adding document to index [1119]
# Adding document to index [1120]
# Adding document to index [1121]
# Adding document to index [1122]
# Adding document to index [1123]
# Adding document to index [1124]
# Adding document to index [1125]
# Adding document to index [1126]
# Adding document to index [1127]
# Adding document to index [1128]
# Adding document to index [1129]
# Adding document to index [1130]
# Adding document to index [1131]
# Adding document to index [1132]
# Adding document to index [1133]
# Adding document to index [1134]
# Adding document to index [1135]
# Adding document to index [1136]
# Adding document to index [1137]
# Adding document to index [1138]
# Adding document to index [1139]
# Adding document to index [1140]
# Adding document to index [1141]
# Adding document to index [1142]
# Adding document to index [1143]
# Adding document to index [1144]
# Adding document to index [1145]
# Adding document to index [1146]
# Adding document to index [1147]
# Adding document to index [1148]
# Adding document to index [1149]
# Adding document to index [1150]
# Adding document to index [1151]
# Adding document to index [1152]
# Adding document to index [1153]
# Adding document to index [1154]
# Adding document to index [1155]
# Adding document to index [1156]
# Adding document to index [1157]
# Adding document to index [1158]
# Adding document to index [1159]
# Adding document to index [1160]
# Adding document to index [1161]
# Adding document to index [1162]
# Adding document to index [1163]
# Adding document to index [1164]
# Adding document to index [1165]
# Adding document to index [1166]
# Adding document to index [1167]
# Adding document to index [1168]
# Adding document to index [1169]
# Adding document to index [1170]
# Adding document to index [1171]
# Adding document to index [1172]
# Adding document to index [1173]
# Adding document to index [1174]
# Adding document to index [1175]
# Adding document to index [1176]
# Adding document to index [1177]
# Adding document to index [1178]
# Adding document to index [1179]
# Adding document to index [1180]
# Adding document to index [1181]
# Adding document to index [1182]
# Adding document to index [1183]
# Adding document to index [1184]
# Adding document to index [1185]
# Adding document to index [1186]
# Adding document to index [1187]
# Adding document to index [1188]
# Adding document to index [1189]
# Adding document to index [1190]
# Adding document to index [1191]
# Adding document to index [1192]
# Adding document to index [1193]
# Adding document to index [1194]
# Adding document to index [1195]
# Adding document to index [1196]
# Adding document to index [1197]
# Adding document to index [1198]
# Adding document to index [1199]
# Adding document to index [1200]
# Adding document to index [1201]
# Adding document to index [1202]
# Adding document to index [1203]
# Adding document to index [1204]
# Adding document to index [1205]
# Adding document to index [1206]
# Adding document to index [1207]
# Adding document to index [1208]
# Adding document to index [1209]
# Adding document to index [1210]
# Adding document to index [1211]
# Adding document to index [1212]
# Adding document to index [1213]
# Adding document to index [1214]
# Adding document to index [1215]
# Adding document to index [1216]
# Adding document to index [1217]
# Adding document to index [1218]
# Adding document to index [1219]
# Adding document to index [1220]
# Adding document to index [1221]
# Adding document to index [1222]
# Adding document to index [1223]
# Adding document to index [1224]
# Adding document to index [1225]
# Adding document to index [1226]
# Adding document to index [1227]
# Adding document to index [1228]
# Adding document to index [1229]
# Adding document to index [1230]
# Adding document to index [1231]
# Adding document to index [1232]
# Adding document to index [1233]
# Adding document to index [1234]
# Adding document to index [1235]
# Adding document to index [1236]
# Adding document to index [1237]
# Adding document to index [1238]
# Adding document to index [1239]
# Adding document to index [1240]
# Adding document to index [1241]
# Adding document to index [1242]
# Adding document to index [1243]
# Adding document to index [1244]
# Adding document to index [1245]
# Adding document to index [1246]
# Adding document to index [1247]
# Adding document to index [1248]
# Adding document to index [1249]
# Adding document to index [1250]
# Adding document to index [1251]
# Adding document to index [1252]
# Adding document to index [1253]
# Adding document to index [1254]
# Adding document to index [1255]
# Adding document to index [1256]
# Adding document to index [1257]
# Adding document to index [1258]
# Adding document to index [1259]
# Adding document to index [1260]
# Adding document to index [1261]
# Adding document to index [1262]
# Adding document to index [1263]
# Adding document to index [1264]
# Adding document to index [1265]
# Adding document to index [1266]
# Adding document to index [1267]
# Adding document to index [1268]
# Adding document to index [1269]
# Adding document to index [1270]
# Adding document to index [1271]
# Adding document to index [1272]
# Adding document to index [1273]
# Adding document to index [1274]
# Adding document to index [1275]
# Adding document to index [1276]
# Adding document to index [1277]
# Adding document to index [1278]
# Adding document to index [1279]
# Adding document to index [1280]
# Adding document to index [1281]
# Adding document to index [1282]
# Adding document to index [1283]
# Adding document to index [1284]
# Adding document to index [1285]
# Adding document to index [1286]
# Adding document to index [1287]
# Adding document to index [1288]
# Adding document to index [1289]
# Adding document to index [1290]
# Adding document to index [1291]
# Adding document to index [1292]
# Adding document to index [1293]
# Adding document to index [1294]
# Adding document to index [1295]
# Adding document to index [1296]
# Adding document to index [1297]
# Adding document to index [1298]
# Adding document to index [1299]
# Adding document to index [1300]
# Adding document to index [1301]
# Adding document to index [1302]
# Adding document to index [1303]
# Adding document to index [1304]
# Adding document to index [1305]
# Adding document to index [1306]
# Adding document to index [1307]
# Adding document to index [1308]
# Adding document to index [1309]
# Adding document to index [1310]
# Adding document to index [1311]
# Adding document to index [1312]
# Adding document to index [1313]
# Adding document to index [1314]
# Adding document to index [1315]
# Adding document to index [1316]
# Adding document to index [1317]
# Adding document to index [1318]
# Adding document to index [1319]
# Adding document to index [1320]
# Adding document to index [1321]
# Adding document to index [1322]
# Adding document to index [1323]
# Adding document to index [1324]
# Adding document to index [1325]
# Adding document to index [1326]
# Adding document to index [1327]
# Adding document to index [1328]
# Adding document to index [1329]
# Adding document to index [1330]
# Adding document to index [1331]
# Adding document to index [1332]
# Adding document to index [1333]
# Adding document to index [1334]
# Adding document to index [1335]
# Adding document to index [1336]
# Adding document to index [1337]
# Adding document to index [1338]
# Adding document to index [1339]
# Adding document to index [1340]
# Adding document to index [1341]
# Adding document to index [1342]
# Adding document to index [1343]
# Adding document to index [1344]
# Adding document to index [1345]
# Adding document to index [1346]
# Adding document to index [1347]
# Adding document to index [1348]
# Adding document to index [1349]
# Adding document to index [1350]
# Adding document to index [1351]
# Adding document to index [1352]
# Adding document to index [1353]
# Adding document to index [1354]
# Adding document to index [1355]
# Adding document to index [1356]
# Adding document to index [1357]
# Adding document to index [1358]
# Adding document to index [1359]
# Adding document to index [1360]
# Adding document to index [1361]
# Adding document to index [1362]
# Adding document to index [1363]
# Adding document to index [1364]
# Adding document to index [1365]
# Adding document to index [1366]
# Adding document to index [1367]
# Adding document to index [1368]
# Adding document to index [1369]
# Adding document to index [1370]
# Adding document to index [1371]
# Adding document to index [1372]
# Adding document to index [1373]
# Adding document to index [1374]
# Adding document to index [1375]
# Adding document to index [1376]
# Adding document to index [1377]
# Adding document to index [1378]
# Adding document to index [1379]
# Adding document to index [1380]
# Adding document to index [1381]
# Adding document to index [1382]
# Adding document to index [1383]
# Adding document to index [1384]
# Adding document to index [1385]
# Adding document to index [1386]
# Adding document to index [1387]
# Adding document to index [1388]
# Adding document to index [1389]
# Adding document to index [1390]
# Adding document to index [1391]
# Adding document to index [1392]
# Adding document to index [1393]
# Adding document to index [1394]
# Adding document to index [1395]
# Adding document to index [1396]
# Adding document to index [1397]
# Adding document to index [1398]
# Adding document to index [1399]
# Adding document to index [1400]

# %% [markdown]
# ## Normal Boolean IR queries
# This set of queries aims to test whether the various IRs can retrieve correctly the documents that match a normal boolean query (no wildcards).

# %% [markdown]
# ### Single term query
# A text search reveals that "statistical" only occurs in documents: 99, 110, 218, 729, 839, 1255, and 1286

# %%
q1 = "statistical"
print(f"Boolean   : " + str(ir1.retrieve(q1)))
print(f"Permuterm : " + str(ir2.retrieve(q1)))
print(f"K-gram    : " + str(ir3.retrieve(q1)))
# Out:
# Boolean   : [99, 110, 218, 729, 839, 1255, 1286]
# Permuterm : [99, 110, 218, 729, 839, 1255, 1286]
# K-gram    : [99, 110, 218, 729, 839, 1255, 1286]

# %% [markdown]
# ### Single phrase query
# A text search reveals that "results are given" only occurs in documents: 98, 369, 413, 475, 477, 514, 545, 558, 606, 610, 619, 632, 671, 751, 755, 776, 844, 891, 963, 1025, 1050, 1145, 1346

# %%
q2 = "results are given"
print(f"Boolean   : " + str(ir1.retrieve(q2)))
print(f"Permuterm : " + str(ir2.retrieve(q2)))
print(f"K-gram    : " + str(ir3.retrieve(q2)))
# Out:
# Boolean   : [98, 369, 413, 475, 477, 514, 545, 558, 606, 610, 619, 632, 671, 751, 755, 776, 844, 891, 963, 1025, 1050, 1145, 1346]
# Permuterm : [98, 369, 413, 475, 477, 514, 545, 558, 606, 610, 619, 632, 671, 751, 755, 776, 844, 891, 963, 1025, 1050, 1145, 1346]
# K-gram    : [98, 369, 413, 475, 477, 514, 545, 558, 606, 610, 619, 632, 671, 751, 755, 776, 844, 891, 963, 1025, 1050, 1145, 1346]

# %% [markdown]
# ### Simple AND query
# A text search reveals that the only document in which "newtonian" and "subsequent" both occur is 110

# %%
q3 = "newtonian AND subsequent"
print(f"Boolean   : " + str(ir1.retrieve(q3)))
print(f"Permuterm : " + str(ir2.retrieve(q3)))
print(f"K-gram    : " + str(ir3.retrieve(q3)))
# Out:
# Boolean   : [110]
# Permuterm : [110]
# K-gram    : [110]

# %% [markdown]
# ### Simple OR query

# %%
q4 = "newtonian OR isentropic"
print(f"Boolean   : " + str(ir1.retrieve(q4)))
print(f"Permuterm : " + str(ir2.retrieve(q4)))
print(f"K-gram    : " + str(ir3.retrieve(q4)))
# Out:
# Boolean   : [20, 27, 28, 35, 36, 58, 64, 97, 110, 118, 122, 144, 169, 232, 276, 317, 360, 370, 372, 423, 473, 495, 567, 593, 634, 635, 688, 689, 719, 775, 814, 947, 949, 999, 1000, 1005, 1011, 1037, 1110, 1124, 1157, 1186, 1191, 1205, 1218, 1231, 1238, 1248, 1258, 1274, 1304, 1307, 1310, 1319, 1356]
# Permuterm : [20, 27, 28, 35, 36, 58, 64, 97, 110, 118, 122, 144, 169, 232, 276, 317, 360, 370, 372, 423, 473, 495, 567, 593, 634, 635, 688, 689, 719, 775, 814, 947, 949, 999, 1000, 1005, 1011, 1037, 1110, 1124, 1157, 1186, 1191, 1205, 1218, 1231, 1238, 1248, 1258, 1274, 1304, 1307, 1310, 1319, 1356]
# K-gram    : [20, 27, 28, 35, 36, 58, 64, 97, 110, 118, 122, 144, 169, 232, 276, 317, 360, 370, 372, 423, 473, 495, 567, 593, 634, 635, 688, 689, 719, 775, 814, 947, 949, 999, 1000, 1005, 1011, 1037, 1110, 1124, 1157, 1186, 1191, 1205, 1218, 1231, 1238, 1248, 1258, 1274, 1304, 1307, 1310, 1319, 1356]

# %% [markdown]
# ### Simple NOT query
# The only documents that do not contain the term "the" are: 405, 557, 1138

# %%
q5 = "NOT the"
print(f"Boolean   : " + str(ir1.retrieve(q5)))
print(f"Permuterm : " + str(ir2.retrieve(q5)))
print(f"K-gram    : " + str(ir3.retrieve(q5)))
# Out:
# Boolean   : [405, 557, 1138]
# Permuterm : [405, 557, 1138]
# K-gram    : [405, 557, 1138]

# %% [markdown]
# ### Complex Boolean query
# This query should return a union of queries q3 and q5

# %%
q6 = "(newtonian AND subsequent) OR NOT the"
print(f"Boolean   : " + str(ir1.retrieve(q6)))
print(f"Permuterm : " + str(ir2.retrieve(q6)))
print(f"K-gram    : " + str(ir3.retrieve(q6)))
# Out:
# Boolean   : [110, 405, 557, 1138]
# Permuterm : [110, 405, 557, 1138]
# K-gram    : [110, 405, 557, 1138]

# %% [markdown]
# ## Wildcard Boolean IR queries
# This set of queries aims to test whether the various IRs can retrieve correctly the documents that match a query which contains wildcards.
# Of course, the base Boolean IR doesn't support wildcards, so it is excluded from these tests.

# %% [markdown]
# ### Prefix wildcard query
# In the Cranfield corpus, this query should only find matches for "statistic", "statistics", or "statistically"

# %%
q7 = "statistic*"
vanilla = set(ir1.retrieve("statistic")).union(set(ir1.retrieve("statistical"))).union(set(ir1.retrieve("statistics"))).union(set(ir1.retrieve("statistically")))
permuterm = ir2.retrieve(q7)
kgram = ir3.retrieve(q7)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : {99, 1286, 839, 1255, 558, 110, 729, 218, 1051}
# Permuterm : [99, 110, 218, 558, 729, 839, 1051, 1255, 1286]
# K-gram    : [99, 110, 218, 558, 729, 839, 1051, 1255, 1286]

# %% [markdown]
# ### Postfix wildcard query
# In the Cranfield corpus, this query should only find matches for "upstream" and "slipstream"

# %%
q8 = "*pstream" # only matches should be upstream, slipstream
vanilla = set(ir1.retrieve("upstream")).union(set(ir1.retrieve("slipstream")))
permuterm = ir2.retrieve(q8)
kgram = ir3.retrieve(q8)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : {1, 1164, 1165, 526, 1166, 656, 529, 276, 1302, 409, 410, 291, 933, 294, 1064, 560, 1202, 1203, 53, 1205, 696, 697, 187, 189, 190, 1089, 1090, 1091, 1092, 453, 1094, 457, 459, 979, 1364, 1367, 472, 1240, 987, 605, 989, 994, 484, 1382, 1383, 490, 364, 1261, 111, 757, 1144, 636}
# Permuterm : [1, 53, 111, 187, 189, 190, 276, 291, 294, 364, 409, 410, 453, 457, 459, 472, 484, 490, 526, 529, 560, 605, 636, 656, 696, 697, 757, 933, 979, 987, 989, 994, 1064, 1089, 1090, 1091, 1092, 1094, 1144, 1164, 1165, 1166, 1202, 1203, 1205, 1240, 1261, 1302, 1364, 1367, 1382, 1383]
# K-gram    : [1, 53, 111, 187, 189, 190, 276, 291, 294, 364, 409, 410, 453, 457, 459, 472, 484, 490, 526, 529, 560, 605, 636, 656, 696, 697, 757, 933, 979, 987, 989, 994, 1064, 1089, 1090, 1091, 1092, 1094, 1144, 1164, 1165, 1166, 1202, 1203, 1205, 1240, 1261, 1302, 1364, 1367, 1382, 1383]

# %% [markdown]
# ### Middle wildcard query
# In the Cranfield corpus, this query should only find matches for "aerodynamic", "aerothermodynamic", "aeronautic", and "aeroelastic"

# %%
q9 = "aero*ic"
vanilla = sorted(set(ir1.retrieve("aerodynamic")).union(set(ir1.retrieve("aeronautic"))).union(set(ir1.retrieve("aerothermodynamic"))).union(set(ir1.retrieve("aeroelastic"))))
permuterm = ir2.retrieve(q9)
kgram = ir3.retrieve(q9)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : [5, 12, 13, 14, 29, 32, 33, 36, 44, 51, 52, 66, 73, 77, 78, 95, 120, 129, 137, 141, 142, 163, 164, 172, 184, 185, 202, 203, 204, 205, 225, 272, 277, 284, 287, 297, 329, 337, 342, 356, 357, 379, 390, 391, 406, 415, 434, 441, 442, 452, 453, 464, 481, 486, 499, 530, 536, 544, 546, 567, 592, 598, 599, 606, 608, 624, 625, 627, 632, 635, 638, 650, 658, 662, 671, 685, 688, 689, 698, 704, 707, 708, 709, 711, 712, 715, 716, 717, 719, 746, 748, 749, 753, 759, 780, 781, 783, 794, 798, 801, 812, 813, 814, 815, 859, 860, 861, 875, 877, 886, 892, 894, 896, 899, 917, 919, 925, 927, 939, 947, 972, 978, 981, 982, 999, 1005, 1008, 1064, 1066, 1089, 1104, 1112, 1115, 1147, 1156, 1162, 1163, 1164, 1195, 1197, 1209, 1213, 1244, 1246, 1259, 1272, 1274, 1289, 1291, 1305, 1314, 1319, 1320, 1328, 1332, 1333, 1334, 1335, 1336, 1339, 1340, 1342, 1343, 1345, 1347, 1352, 1361, 1379, 1380, 1391]
# Permuterm : [5, 12, 13, 14, 29, 32, 33, 36, 44, 51, 52, 66, 73, 77, 78, 95, 120, 129, 137, 141, 142, 163, 164, 172, 184, 185, 202, 203, 204, 205, 225, 272, 277, 284, 287, 297, 329, 337, 342, 356, 357, 379, 390, 391, 406, 415, 434, 441, 442, 452, 453, 464, 481, 486, 499, 530, 536, 544, 546, 567, 592, 598, 599, 606, 608, 624, 625, 627, 632, 635, 638, 650, 658, 662, 671, 685, 688, 689, 698, 704, 707, 708, 709, 711, 712, 715, 716, 717, 719, 746, 748, 749, 753, 759, 780, 781, 783, 794, 798, 801, 812, 813, 814, 815, 859, 860, 861, 875, 877, 886, 892, 894, 896, 899, 917, 919, 925, 927, 939, 947, 972, 978, 981, 982, 999, 1005, 1008, 1064, 1066, 1089, 1104, 1112, 1115, 1147, 1156, 1162, 1163, 1164, 1195, 1197, 1209, 1213, 1244, 1246, 1259, 1272, 1274, 1289, 1291, 1305, 1314, 1319, 1320, 1328, 1332, 1333, 1334, 1335, 1336, 1339, 1340, 1342, 1343, 1345, 1347, 1352, 1361, 1379, 1380, 1391]
# K-gram    : [5, 12, 13, 14, 29, 32, 33, 36, 44, 51, 52, 66, 73, 77, 78, 95, 120, 129, 137, 141, 142, 163, 164, 172, 184, 185, 202, 203, 204, 205, 225, 272, 277, 284, 287, 297, 329, 337, 342, 356, 357, 379, 390, 391, 406, 415, 434, 441, 442, 452, 453, 464, 481, 486, 499, 530, 536, 544, 546, 567, 592, 598, 599, 606, 608, 624, 625, 627, 632, 635, 638, 650, 658, 662, 671, 685, 688, 689, 698, 704, 707, 708, 709, 711, 712, 715, 716, 717, 719, 746, 748, 749, 753, 759, 780, 781, 783, 794, 798, 801, 812, 813, 814, 815, 859, 860, 861, 875, 877, 886, 892, 894, 896, 899, 917, 919, 925, 927, 939, 947, 972, 978, 981, 982, 999, 1005, 1008, 1064, 1066, 1089, 1104, 1112, 1115, 1147, 1156, 1162, 1163, 1164, 1195, 1197, 1209, 1213, 1244, 1246, 1259, 1272, 1274, 1289, 1291, 1305, 1314, 1319, 1320, 1328, 1332, 1333, 1334, 1335, 1336, 1339, 1340, 1342, 1343, 1345, 1347, 1352, 1361, 1379, 1380, 1391]

# %% [markdown]
# ### Wildcard phrase query
# In the Cranfield corpus, this query should only find matches for "aerodynamic and" and "aerodynamics and"

# %%
q10 = "aerodynamic* and"
vanilla = sorted(set(ir1.retrieve("aerodynamic and")).union(set(ir1.retrieve("aerodynamics and"))))
permuterm = ir2.retrieve(q10)
kgram = ir3.retrieve(q10)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : [44, 634, 1314, 1331, 1347]
# Permuterm : [44, 634, 1314, 1331, 1347]
# K-gram    : [44, 634, 1314, 1331, 1347]

# %% [markdown]
# ### Multiple wildcards query
# In the Cranfield corpus, this query should only find matches for "necessary", "necessarily", "unnecessary" and "unnecessarily"

# %%
q11 = "*necessar*"
vanilla = sorted(set(ir1.retrieve("necessary")).union(set(ir1.retrieve("necessarily"))).union(set(ir1.retrieve("unnecessary"))).union(set(ir1.retrieve("unnecessarily"))))
permuterm = ir2.retrieve(q11)
kgram = ir3.retrieve(q11)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : [2, 17, 42, 44, 49, 82, 94, 147, 158, 179, 184, 188, 196, 202, 212, 214, 216, 217, 220, 231, 249, 315, 329, 341, 349, 355, 356, 368, 406, 412, 417, 470, 480, 518, 529, 551, 552, 640, 645, 652, 665, 710, 721, 739, 777, 796, 800, 874, 893, 904, 927, 946, 986, 1025, 1042, 1117, 1197, 1209, 1216, 1246, 1248, 1251, 1252, 1257, 1280, 1302, 1325, 1342, 1343, 1361, 1387, 1392, 1398]
# Permuterm : [2, 17, 42, 44, 49, 82, 94, 147, 158, 179, 184, 188, 196, 202, 212, 214, 216, 217, 220, 231, 249, 315, 329, 341, 349, 355, 356, 368, 406, 412, 417, 470, 480, 518, 529, 551, 552, 640, 645, 652, 665, 710, 721, 739, 777, 796, 800, 874, 893, 904, 927, 946, 986, 1025, 1042, 1117, 1197, 1209, 1216, 1246, 1248, 1251, 1252, 1257, 1280, 1302, 1325, 1342, 1343, 1361, 1387, 1392, 1398]
# K-gram    : [2, 17, 42, 44, 49, 82, 94, 147, 158, 179, 184, 188, 196, 202, 212, 214, 216, 217, 220, 231, 249, 315, 329, 341, 349, 355, 356, 368, 406, 412, 417, 470, 480, 518, 529, 551, 552, 640, 645, 652, 665, 710, 721, 739, 777, 796, 800, 874, 893, 904, 927, 946, 986, 1025, 1042, 1117, 1197, 1209, 1216, 1246, 1248, 1251, 1252, 1257, 1280, 1302, 1325, 1342, 1343, 1361, 1387, 1392, 1398]

# %% [markdown]
# ### Multiple wildcards phrase query
# In the Cranfield corpus, this query should only find matches for "necessary to", "necessarily to", "unnecessary to" and "unnecessarily to"

# %%
q12 = "*necessar* to"
vanilla = sorted(set(ir1.retrieve("necessary to")).union(set(ir1.retrieve("necessarily to"))).union(set(ir1.retrieve("unnecessary to"))).union(set(ir1.retrieve("unnecessarily to"))))
permuterm = ir2.retrieve(q12)
kgram = ir3.retrieve(q12)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : [2, 17, 42, 94, 212, 249, 315, 341, 349, 355, 368, 412, 470, 480, 518, 552, 652, 710, 721, 739, 927, 946, 1197, 1251, 1280, 1342, 1392, 1398]
# Permuterm : [2, 17, 42, 94, 212, 249, 315, 341, 349, 355, 368, 412, 470, 480, 518, 552, 652, 710, 721, 739, 927, 946, 1197, 1251, 1280, 1342, 1392, 1398]
# K-gram    : [2, 17, 42, 94, 212, 249, 315, 341, 349, 355, 368, 412, 470, 480, 518, 552, 652, 710, 721, 739, 927, 946, 1197, 1251, 1280, 1342, 1392, 1398]

# %% [markdown]
# ### Multiple wildcards phrase Boolean query
# In the Cranfield corpus, this query should only find matches for documents 212, 946, and 1342

# %%
q13 = "*necessar* to AND total"
vanilla = sorted(set(ir1.retrieve("necessary to AND total")).union(set(ir1.retrieve("necessarily to AND total"))).union(set(ir1.retrieve("unnecessary to AND total"))).union(set(ir1.retrieve("unnecessarily to AND total"))))
permuterm = ir2.retrieve(q13)
kgram = ir3.retrieve(q13)
print(f"Vanilla   : " + str(vanilla))
print(f"Permuterm : " + str(permuterm))
print(f"K-gram    : " + str(kgram))
# Out:
# Vanilla   : [212, 946, 1342]
# Permuterm : [212, 946, 1342]
# K-gram    : [212, 946, 1342]
